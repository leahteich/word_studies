# %%
import pandas as pd
import numpy as np

# %%
len_data = pd.read_csv("length_df_final.csv")

# %%
len_data
# Out:
#       Unnamed: 0        Word1     Word2  Word1_Length  Word2_Length  \
# 0              0  precipitous     steep            11             5
# 1              1  precipitous     steep            11             5
# 2              2       abrupt     steep             6             5
# 3              3       infuse     steep             6             5
# 4              4   mysterious  mystical            10             8
# ...          ...          ...       ...           ...           ...
# 4916        4916        start     bulge             5             5
# 4917        4917     announce     usher             8             5
# 4918        4918      falsify     alter             7             5
# 4919        4919        braid      lace             5             4
# 4920        4920   intimidate     bully            10             5
#
#       Freq_Per_Mil1  Log_Freq_Per_Mil1  Freq_Per_Mil2  Log_Freq_Per_Mil2  \
# 0              0.12             0.8451           2.45             2.1004
# ...

# %%
commonality = []

for index, row in len_data.iterrows():
    if row['Word2_Length'] == 5: 
        if row['Word1_Length'] == 9:
            commonality.append(row["Freq_Per_Mil1"]/row["Freq_Per_Mil2"])

sum(commonality)/len(commonality)
# Out:
# 0.8770322198628728
